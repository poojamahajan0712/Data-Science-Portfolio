# %% [markdown]
# <a href="https://colab.research.google.com/github/poojamahajan0712/Data-Science-Portfolio/blob/main/Computer%20Vision/Corn_Disease_Detection/CornDiseaseDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
import pathlib
import PIL
# Out:
# 2.17.0

# %%
dataset_path = "/content/drive/MyDrive/Corn_disease_dataset/data"
data_dir = pathlib.Path(dataset_path)
tot_count = {}
for folder in data_dir.iterdir():
    image_count = len(list(folder.glob('*.[jJ][pP][gG]')))
    tot_count[folder.name] = image_count

tot_count
# Out:
# {'Gray_Leaf_Spot': 574, 'Blight': 1145, 'Common_Rust': 1306, 'Healthy': 1162}

# %% [markdown]
# Lets view all types of diseases and healthy class

# %%
PIL.Image.open("/content/drive/MyDrive/Corn_disease_dataset/data/Blight/Corn_Blight (1003).JPG")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
PIL.Image.open("/content/drive/MyDrive/Corn_disease_dataset/data/Common_Rust/Corn_Common_Rust (1005).JPG")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
PIL.Image.open("/content/drive/MyDrive/Corn_disease_dataset/data/Gray_Leaf_Spot/Corn_Gray_Spot (101).JPG")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
PIL.Image.open("/content/drive/MyDrive/Corn_disease_dataset/data/Healthy/Corn_Health (10).jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# *  images are of different sizes, need to resize
# * we have jpg,JPG format of data for four folders
