# %%
# !pip install openpyxl  --quiet
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 3.9 MB/s  eta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
PATH = '/kaggle/input/utility-script'
import sys
sys.path.insert(1, PATH)
from script import *

# %%
import re
import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
df = pd.read_excel('../input/inshorts-news-data/Inshorts Cleaned Data.xlsx',engine='openpyxl')

print(df.shape)
df.head()
# Out:
# (55104, 5)
#                                             Headline  \
# 0  4 ex-bank officials booked for cheating bank o...
# 1     Supreme Court to go paperless in 6 months: CJI
# 2  At least 3 killed, 30 injured in blast in Sylh...
# 3  Why has Reliance been barred from trading in f...
# 4  Was stopped from entering my own studio at Tim...
#
#                                                Short                 Source   \
# 0  The CBI on Saturday booked four former officia...  The New Indian Express
# 1  Chief Justice JS Khehar has said the Supreme C...                 Outlook
# 2  At least three people were killed, including a...         Hindustan Times
# 3  Mukesh Ambani-led Reliance Industries (RIL) wa...                Livemint
# 4  TV news anchor Arnab Goswami has said he was t...                 YouTube
#
#       Time  Publish Date
# 0  09:25:00   2017-03-26
# 1  22:18:00   2017-03-25
# 2  23:39:00   2017-03-25
# 3  23:08:00   2017-03-25
# 4  23:24:00   2017-03-25

# %%
df['Source '].nunique()
# Out:
# 1471

# %%
# @title Publish Date vs count()
temp = df['Publish Date'].value_counts()
temp.plot()
plt.title('Publish Date vs count()')
plt.xlabel('Publish Date')
plt.ylabel('count()')
## data for around 1 year 3 months
## count peaked at sep to nov 2016 , shows increasing trend overall
# Out:
# Text(0, 0.5, 'count()')

# %%
# @title Most Frequent News Sources
df['Source '].value_counts().head(10).plot(kind='barh')
plt.title('Most Frequent News Sources')
plt.xlabel('Frequency')
_ = plt.ylabel('News Source')

## around 1471 sources, on checking the top sources we have maximum contribution from Youtube

# %%
# @title Sentence length distribution
df['Headline_length'] = df['Headline'].apply(lambda x : len(x.split(' ')))
df['Short_length'] = df['Short'].apply(lambda x : len(x.split(' ')))
df[['Headline_length','Short_length']].describe()

## headline are mostly around 9 words long, shorts are around 60 words long
## using this reference for encoder and decoder len
# Out:
#        Headline_length  Short_length
# count     55104.000000  55104.000000
# mean          8.288110     58.316257
# std           1.539975      2.423718
# min           3.000000     40.000000
# 25%           7.000000     57.000000
# 50%           8.000000     59.000000
# 75%           9.000000     60.000000
# max          14.000000     83.000000

# %%
df['Headline_length'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Short_length'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Preprocessing

# %%
#@title Data Preprocessing
## Step1 Data Cleaning

def preprocess(text):
    text = '<SOS> ' + text + ' <EOS>'
    text = re.sub(r"&.[1-9]+;"," ",text) ## removing only html tags
    return text


article = df['Short']
summary = df['Headline']

article = article.apply(lambda x: preprocess(x))
summary = summary.apply(lambda x: preprocess(x))

## 90%-10% division 
article_test = article[9000:10000]
summary_test = summary[9000:10000]

article = article[:9000]
summary = summary[:9000]

# %%
article_test.shape
# Out:
# (1000,)

# %%
article[0]
# Out:
# '<SOS> The CBI on Saturday booked four former officials of Syndicate Bank and six others for cheating, forgery, criminal conspiracy and causing ₹209 crore loss to the state-run bank. The accused had availed home loans and credit from Syndicate Bank on the basis of forged and fabricated documents. These funds were fraudulently transferred to the companies owned by the accused persons. <EOS>'

# %%
summary[0]
# Out:
# '<SOS> 4 ex-bank officials booked for cheating bank of ₹209 crore <EOS>'

# %%
## Step2  Tokenising , padding
#  here we will be creating two tokenisers for summary and main news , while in language translation we created two tokenisers,
# here although the language is same but due different vocab distributions in summary and main news , will be having different token limits and
# it provides flexibility in terms of encoder decoder architecture also.

filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'
oov_token = '<unk>'
article_tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token=oov_token)
summary_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters=filters, oov_token=oov_token)
## fitting on training data 
article_tokenizer.fit_on_texts(article)
summary_tokenizer.fit_on_texts(summary)

## applying on training and test data
inputs = article_tokenizer.texts_to_sequences(article)
targets = summary_tokenizer.texts_to_sequences(summary)

inputs_test = article_tokenizer.texts_to_sequences(article_test)
targets_test = summary_tokenizer.texts_to_sequences(summary_test)

# %%
# By adding 1 to the vocabulary size, we make space for special tokens,padding,etc.
# Even if we are not explicitly adding special tokens in the Tokenizer itself, 
#some layers in TensorFlow/Keras may assume the presence of a default padding token.

ENCODER_VOCAB = len(article_tokenizer.word_index) + 1
DECODER_VOCAB = len(summary_tokenizer.word_index) + 1
print(ENCODER_VOCAB, DECODER_VOCAB)

## we can see considerable difference in the vocabulary size of article and summary , as expected
# Out:
# 29825 12850

# %%
# these lengths are taken in reference to article and summary lengths.
ENCODER_LEN = 100
DECODER_LEN = 20
BATCH_SIZE = 64
BUFFER_SIZE = BATCH_SIZE*8

# %%
#Step 3 - padding the sequences
inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs, maxlen=ENCODER_LEN, padding='post', truncating='post')
targets = tf.keras.preprocessing.sequence.pad_sequences(targets, maxlen=DECODER_LEN, padding='post', truncating='post')
inputs = tf.cast(inputs, dtype=tf.int64)
targets = tf.cast(targets, dtype=tf.int64)

inputs_test = tf.keras.preprocessing.sequence.pad_sequences(inputs_test, maxlen=ENCODER_LEN, padding='post', truncating='post')
targets_test = tf.keras.preprocessing.sequence.pad_sequences(targets_test, maxlen=DECODER_LEN, padding='post', truncating='post')
inputs_test = tf.cast(inputs_test, dtype=tf.int64)
targets_test = tf.cast(targets_test, dtype=tf.int64)

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, targets)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset_test = tf.data.Dataset.from_tensor_slices((inputs_test, targets_test)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ## Model Training

# %%
num_layers = 5
d_model = 128
dff = 512
num_heads = 4
dropout_rate = 0.2
EPOCHS = 80

# %%
# !rm -rf /kaggle/working/checkpoints

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.Mean(name='test_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=ENCODER_VOCAB,
    target_vocab_size=DECODER_VOCAB,
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        predictions, _ = transformer(
            inp, tar_inp, 
            True, 
            enc_padding_mask, 
            combined_mask, 
            dec_padding_mask
        )
        loss = loss_function(loss_object,tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)
    train_accuracy(accuracy_function(tar_real, predictions))
    
@tf.function
def test_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    predictions, _ = transformer(
            inp, tar_inp, 
            True, 
            enc_padding_mask, 
            combined_mask, 
            dec_padding_mask
        )
    loss = loss_function(loss_object,tar_real, predictions)


    test_loss(loss)
    test_accuracy(accuracy_function(tar_real, predictions))

# %%
checkpoint_path = "checkpoints"

ckpt = tf.train.Checkpoint(transformer=transformer, optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')

# %%
for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()
    test_loss.reset_states()
  
    for (batch, (inp, tar)) in enumerate(dataset):
        train_step(inp, tar)

    for (batch, (inp, tar)) in enumerate(dataset_test):
        test_step(inp, tar)
    
    if (epoch + 1) % 10 == 0:
        ckpt_save_path = ckpt_manager.save()
       
   
    print(f'Epoch {epoch + 1} Train Loss {train_loss.result():.4f} Train Accuracy {train_accuracy.result():.4f}')
    print(f'Epoch {epoch + 1} Test Loss {test_loss.result():.4f} Test Accuracy {test_accuracy.result():.4f}')
    
    print('\n')
# Out:
# Epoch 1 Train Loss 9.2849 Train Accuracy 0.0770
# Epoch 1 Test Loss 9.0679 Test Accuracy 0.0951
#
#
# Epoch 2 Train Loss 8.7127 Train Accuracy 0.0856
# Epoch 2 Test Loss 8.3687 Test Accuracy 0.0951
#
#
# Epoch 3 Train Loss 7.8977 Train Accuracy 0.0885
# Epoch 3 Test Loss 7.6910 Test Accuracy 0.0950
#
#
# Epoch 4 Train Loss 7.4174 Train Accuracy 0.0902
# Epoch 4 Test Loss 7.5380 Test Accuracy 0.0984
#
#
# Epoch 5 Train Loss 7.2638 Train Accuracy 0.0949
# Epoch 5 Test Loss 7.4980 Test Accuracy 0.1020
#
#
# Epoch 6 Train Loss 7.1206 Train Accuracy 0.0992
# Epoch 6 Test Loss 7.4550 Test Accuracy 0.1050
#
#
# Epoch 7 Train Loss 6.9389 Train Accuracy 0.1036
# Epoch 7 Test Loss 7.4263 Test Accuracy 0.1085
#
#
# Epoch 8 Train Loss 6.7314 Train Accuracy 0.1077
# Epoch 8 Test Loss 7.3935 Test Accuracy 0.1112
#
#
# Epoch 9 Train Loss 6.5206 Train Accuracy 0.1115
# Epoch 9 Test Loss 7.3562 Test Accuracy 0.1133
#
#
# Epoch 10 Train Loss 6.3084 Train Accuracy 0.1151
# Epoch 10 Test Loss 7.3580 Test Accuracy 0.1150
#
#
# Epoch 11 Train Loss 6.1035 Train Accuracy 0.1188
# Epoch 11 Test Loss 7.3338 Test Accuracy 0.1162
#
#
# Epoch 12 Train Loss 5.9082 Train Accuracy 0.1224
# Epoch 12 Test Loss 7.3206 Test Accuracy 0.1176
#
#
# Epoch 13 Train Loss 5.7237 Train Accuracy 0.1259
# Epoch 13 Test Loss 7.3842 Test Accuracy 0.1190
#
#
# Epoch 14 Train Loss 5.5424 Train Accuracy 0.1295
# Epoch 14 Test Loss 7.3259 Test Accuracy 0.1200
#
#
# Epoch 15 Train Loss 5.3697 Train Accuracy 0.1332
# Epoch 15 Test Loss 7.3789 Test Accuracy 0.1208
#
#
# Epoch 16 Train Loss 5.1962 Train Accuracy 0.1369
# Epoch 16 Test Loss 7.3923 Test Accuracy 0.1218
#
#
# Epoch 17 Train Loss 5.0341 Train Accuracy 0.1406
# Epoch 17 Test Loss 7.4498 Test Accuracy 0.1227
#
#
# Epoch 18 Train Loss 4.8658 Train Accuracy 0.1444
# Epoch 18 Test Loss 7.3281 Test Accuracy 0.1236
#
#
# Epoch 19 Train Loss 4.6964 Train Accuracy 0.1482
# Epoch 19 Test Loss 7.4582 Test Accuracy 0.1243
#
#
# Epoch 20 Train Loss 4.5384 Train Accuracy 0.1523
# Epoch 20 Test Loss 7.5411 Test Accuracy 0.1252
#
#
# Epoch 21 Train Loss 4.3725 Train Accuracy 0.1564
# Epoch 21 Test Loss 7.4955 Test Accuracy 0.1258
#
#
# Epoch 22 Train Loss 4.2016 Train Accuracy 0.1608
# Epoch 22 Test Loss 7.6375 Test Accuracy 0.1265
#
#
# Epoch 23 Train Loss 4.0404 Train Accuracy 0.1654
# Epoch 23 Test Loss 7.5606 Test Accuracy 0.1272
#
#
# Epoch 24 Train Loss 3.8718 Train Accuracy 0.1702
# Epoch 24 Test Loss 7.5972 Test Accuracy 0.1279
#
#
# Epoch 25 Train Loss 3.6983 Train Accuracy 0.1754
# Epoch 25 Test Loss 7.7005 Test Accuracy 0.1288
#
#
# Epoch 26 Train Loss 3.5272 Train Accuracy 0.1809
# Epoch 26 Test Loss 7.7721 Test Accuracy 0.1294
#
#
# Epoch 27 Train Loss 3.3612 Train Accuracy 0.1867
# Epoch 27 Test Loss 7.8269 Test Accuracy 0.1301
#
#
# Epoch 28 Train Loss 3.1965 Train Accuracy 0.1929
# Epoch 28 Test Loss 7.8674 Test Accuracy 0.1307
#
#
# Epoch 29 Train Loss 3.0266 Train Accuracy 0.1996
# Epoch 29 Test Loss 7.9885 Test Accuracy 0.1311
#
#
# Epoch 30 Train Loss 2.8378 Train Accuracy 0.2067
# Epoch 30 Test Loss 8.0170 Test Accuracy 0.1316
#
#
# Epoch 31 Train Loss 2.6454 Train Accuracy 0.2143
# Epoch 31 Test Loss 8.2867 Test Accuracy 0.1323
#
#
# Epoch 32 Train Loss 2.4811 Train Accuracy 0.2223
# Epoch 32 Test Loss 8.4307 Test Accuracy 0.1327
#
#
# Epoch 33 Train Loss 2.3241 Train Accuracy 0.2305
# Epoch 33 Test Loss 8.5412 Test Accuracy 0.1331
#
#
# Epoch 34 Train Loss 2.1729 Train Accuracy 0.2390
# Epoch 34 Test Loss 8.6469 Test Accuracy 0.1336
#
#
# Epoch 35 Train Loss 2.0289 Train Accuracy 0.2477
# Epoch 35 Test Loss 8.7276 Test Accuracy 0.1340
#
#
# Epoch 36 Train Loss 1.9014 Train Accuracy 0.2566
# Epoch 36 Test Loss 8.9425 Test Accuracy 0.1343
#
#
# Epoch 37 Train Loss 1.7888 Train Accuracy 0.2654
# Epoch 37 Test Loss 9.0628 Test Accuracy 0.1347
#
#
# Epoch 38 Train Loss 1.6679 Train Accuracy 0.2745
# Epoch 38 Test Loss 9.0860 Test Accuracy 0.1351
#
#
# Epoch 39 Train Loss 1.5772 Train Accuracy 0.2835
# Epoch 39 Test Loss 9.2922 Test Accuracy 0.1354
#
#
# Epoch 40 Train Loss 1.4808 Train Accuracy 0.2925
# Epoch 40 Test Loss 9.4218 Test Accuracy 0.1356
#
#
# Epoch 41 Train Loss 1.3963 Train Accuracy 0.3015
# Epoch 41 Test Loss 9.4548 Test Accuracy 0.1360
#
#
# Epoch 42 Train Loss 1.3239 Train Accuracy 0.3103
# Epoch 42 Test Loss 9.5554 Test Accuracy 0.1362
#
#
# Epoch 43 Train Loss 1.2549 Train Accuracy 0.3191
# Epoch 43 Test Loss 9.7239 Test Accuracy 0.1365
#
#
# Epoch 44 Train Loss 1.1886 Train Accuracy 0.3278
# Epoch 44 Test Loss 9.8192 Test Accuracy 0.1366
#
#
# Epoch 45 Train Loss 1.1178 Train Accuracy 0.3364
# Epoch 45 Test Loss 9.9370 Test Accuracy 0.1369
#
#
# Epoch 46 Train Loss 1.0737 Train Accuracy 0.3448
# Epoch 46 Test Loss 9.9847 Test Accuracy 0.1371
#
#
# Epoch 47 Train Loss 1.0197 Train Accuracy 0.3532
# Epoch 47 Test Loss 10.0704 Test Accuracy 0.1374
#
#
# Epoch 48 Train Loss 0.9723 Train Accuracy 0.3614
# Epoch 48 Test Loss 10.2267 Test Accuracy 0.1376
#
#
# Epoch 49 Train Loss 0.9265 Train Accuracy 0.3695
# Epoch 49 Test Loss 10.3150 Test Accuracy 0.1379
#
#
# Epoch 50 Train Loss 0.8914 Train Accuracy 0.3774
# Epoch 50 Test Loss 10.3718 Test Accuracy 0.1381
#
#
# Epoch 51 Train Loss 0.8400 Train Accuracy 0.3852
# Epoch 51 Test Loss 10.4131 Test Accuracy 0.1383
#
#
# Epoch 52 Train Loss 0.8186 Train Accuracy 0.3928
# Epoch 52 Test Loss 10.5342 Test Accuracy 0.1385
#
#
# Epoch 53 Train Loss 0.7797 Train Accuracy 0.4003
# Epoch 53 Test Loss 10.6732 Test Accuracy 0.1386
#
#
# Epoch 54 Train Loss 0.7561 Train Accuracy 0.4076
# Epoch 54 Test Loss 10.6972 Test Accuracy 0.1388
#
#
# Epoch 55 Train Loss 0.7221 Train Accuracy 0.4148
# Epoch 55 Test Loss 10.7231 Test Accuracy 0.1390
#
#
# Epoch 56 Train Loss 0.6920 Train Accuracy 0.4219
# Epoch 56 Test Loss 10.8041 Test Accuracy 0.1391
#
#
# Epoch 57 Train Loss 0.6703 Train Accuracy 0.4289
# Epoch 57 Test Loss 10.8872 Test Accuracy 0.1393
#
#
# Epoch 58 Train Loss 0.6414 Train Accuracy 0.4357
# Epoch 58 Test Loss 10.8627 Test Accuracy 0.1395
#
#
# Epoch 59 Train Loss 0.6228 Train Accuracy 0.4423
# Epoch 59 Test Loss 11.0142 Test Accuracy 0.1396
#
#
# Epoch 60 Train Loss 0.6016 Train Accuracy 0.4488
# Epoch 60 Test Loss 11.1281 Test Accuracy 0.1396
#
#
# Epoch 61 Train Loss 0.5886 Train Accuracy 0.4552
# Epoch 61 Test Loss 11.1100 Test Accuracy 0.1398
#
#
# Epoch 62 Train Loss 0.5640 Train Accuracy 0.4614
# Epoch 62 Test Loss 11.1874 Test Accuracy 0.1400
#
#
# Epoch 63 Train Loss 0.5446 Train Accuracy 0.4675
# Epoch 63 Test Loss 11.2415 Test Accuracy 0.1401
#
#
# Epoch 64 Train Loss 0.5278 Train Accuracy 0.4735
# Epoch 64 Test Loss 11.2865 Test Accuracy 0.1402
#
#
# Epoch 65 Train Loss 0.5146 Train Accuracy 0.4794
# Epoch 65 Test Loss 11.3374 Test Accuracy 0.1404
#
#
# Epoch 66 Train Loss 0.5005 Train Accuracy 0.4852
# Epoch 66 Test Loss 11.3617 Test Accuracy 0.1405
#
#
# Epoch 67 Train Loss 0.4922 Train Accuracy 0.4908
# Epoch 67 Test Loss 11.3917 Test Accuracy 0.1406
#
#
# Epoch 68 Train Loss 0.4670 Train Accuracy 0.4964
# Epoch 68 Test Loss 11.5103 Test Accuracy 0.1407
#
#
# Epoch 69 Train Loss 0.4544 Train Accuracy 0.5018
# Epoch 69 Test Loss 11.4908 Test Accuracy 0.1408
#
#
# Epoch 70 Train Loss 0.4462 Train Accuracy 0.5071
# Epoch 70 Test Loss 11.5807 Test Accuracy 0.1409
#
#
# Epoch 71 Train Loss 0.4293 Train Accuracy 0.5124
# Epoch 71 Test Loss 11.5299 Test Accuracy 0.1410
#
#
# Epoch 72 Train Loss 0.4199 Train Accuracy 0.5175
# Epoch 72 Test Loss 11.6492 Test Accuracy 0.1412
#
#
# Epoch 73 Train Loss 0.4151 Train Accuracy 0.5225
# Epoch 73 Test Loss 11.5586 Test Accuracy 0.1414
#
#
# Epoch 74 Train Loss 0.4068 Train Accuracy 0.5274
# Epoch 74 Test Loss 11.6799 Test Accuracy 0.1414
#
#
# Epoch 75 Train Loss 0.3944 Train Accuracy 0.5322
# Epoch 75 Test Loss 11.6851 Test Accuracy 0.1415
#
#
# Epoch 76 Train Loss 0.3802 Train Accuracy 0.5369
# Epoch 76 Test Loss 11.7319 Test Accuracy 0.1416
#
#
# Epoch 77 Train Loss 0.3743 Train Accuracy 0.5416
# Epoch 77 Test Loss 11.8027 Test Accuracy 0.1417
#
#
# Epoch 78 Train Loss 0.3667 Train Accuracy 0.5461
# Epoch 78 Test Loss 11.8112 Test Accuracy 0.1418
#
#
# Epoch 79 Train Loss 0.3615 Train Accuracy 0.5505
# Epoch 79 Test Loss 11.8202 Test Accuracy 0.1420
#
#
# Epoch 80 Train Loss 0.3469 Train Accuracy 0.5549
# Epoch 80 Test Loss 11.8607 Test Accuracy 0.1421

# %% [markdown]
# ## Model Evaluation

# %%
def summarize(input_article):
    summarized = evaluate(input_article,article_tokenizer,ENCODER_LEN,summary_tokenizer,DECODER_LEN,transformer)[0].numpy()
    summarized = np.expand_dims(summarized[:], 0)  
    return summary_tokenizer.sequences_to_texts(summarized)[0]

# %%
article[100]
# Out:
# '<SOS> Indian spinner Ravichandran Ashwin has broken the record for most wickets in a single Test season, taking his 79th this season during the Dharamsala Test against Australia on Saturday. Ashwin went past South African pacer Dale Steyn, who had claimed 78 wickets in 12 Tests in 2007-08. Ashwin has taken seven five-wicket hauls this season in 13 matches. <EOS>'

# %%
print("Actual Headline : ", summary[100],"\n Predicted Summary : ", summarize(article[100]))
# Out:
# Actual Headline :  <SOS> Ashwin breaks record for most wickets in a Test season <EOS>
#  Predicted Summary :  <sos> ashwin breaks 52 breaks 52 by the first ever test season

# %%
article[118]
# Out:
# '<SOS> Twenty-two-year-old jawan Roshan Kumar, who passed away in a road accident in Delhi last week, saved the lives of transplant patients by donating six of his vital organs. Roshan had suffered serious brain injuries in the accident.  Roshan is not at the border to protect the country. But... he served the nation by saving six lives,  said his uncle.  <EOS>'

# %%
print("Actual Headline : ", summary[118],"\nPredicted Summary : ", summarize(article[118]))
# Out:
# Actual Headline :  <SOS> Jawan killed in accident saves lives by donating 6 organs <EOS>
# Predicted Summary :  <sos> jawan killed in accident saves lives by donating 6 organs

# %%
article_test[9005]
# Out:
# '<SOS> After his recent extradition to the US, Mexican druglord Joaquin  El Chapo  Guzman is being held at New York s Metropolitan Correctional Center, described by an inmate as worse than Guantanamo Bay. Interestingly, two inmates had escaped from the maximum security prison in 1990. El Chapo was captured last year for the third time, after escaping top-security prisons twice. <EOS>'

# %%
print("Actual Headline : ", summary_test[9005],"\nPredicted Summary : ", summarize(article_test[9005]))
# Out:
# Actual Headline :  <SOS> 2 prisoners had escaped from jail holding druglord El Chapo <EOS>
# Predicted Summary :  <sos> madrid stars meet teen who guided rescuers to plane crash
